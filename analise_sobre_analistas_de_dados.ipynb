# %%
import pandas as pd

# %%
df=pd.read_excel("state_of_data_(para-iloc)_.xlsx")

# %% [markdown]
# ## Cargo salário e tempo de experiência

# %%
df=df[df['cargo_atual'].notnull()]
df[['cargo_atual','salario',"('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')"]].value_counts().to_frame().head(50)
# Out:
#                                                                                                                                    0
# cargo_atual                                  salario                          ('P2_i ', 'Quanto tempo de experiência na área ...
# Cientista de Dados/Data Scientist            de R$ 6.001/mês a R$ 8.000/mês   de 2 a 3 anos                                       37
# Analista de BI/BI Analyst/Analytics Engineer de R$ 4.001/mês a R$ 6.000/mês   de 2 a 3 anos                                       34
# Cientista de Dados/Data Scientist            de R$ 8.001/mês a R$ 12.000/mês  de 2 a 3 anos                                       34
#                                                                               de 4 a 5 anos                                       31
# Engenheiro de Dados/Data Engineer            de R$ 6.001/mês a R$ 8.000/mês   de 2 a 3 anos                                       25
# ...

# %% [markdown]
# ## Quais das fontes de dados listadas você já analisou ou processou no trabalho

# %%
df["('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')"].value_counts().to_frame()
# Out:
#                                                     ('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')
# Ciência de Dados                                                                                  412
# Dados relacionais (estruturados em bancos SQL),...                                                200
# Dados relacionais (estruturados em bancos SQL),...                                                122
# Dados relacionais (estruturados em bancos SQL),...                                                 81
# Dados relacionais (estruturados em bancos SQL),...                                                 73
# ...                                                                                               ...
# Textos/Documentos, Dados armazenados em bancos ...                                                  1
# Dados relacionais (estruturados em bancos SQL),...                                                  1
# ...

# %% [markdown]
# ## Fazer só com quem utiliza Python

# %%
df["('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')"].value_counts().to_frame()
# Out:
#                                              ('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')
# SQL                                                                                        684
# Python                                                                                     421
# 0                                                                                          410
# Não utilizo nenhuma das linguagens listadas                                                163
# R                                                                                           51
# Visual Basic/VBA                                                                            45
# JavaScript                                                                                  21
# Scala                                                                                       17
# ...

# %% [markdown]
# ## Ver power Bi

# %%
df["('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')"].value_counts().to_frame()
# Out:
#                                                     ('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')
# 0                                                                                                 378
# Microsoft PowerBI                                                                                 315
# Não utilizo nenhuma ferramenta de BI no trabalho                                                  107
# Fazemos todas as análises utilizando apenas Exc...                                                 60
# Tableau                                                                                            49
# ...                                                                                               ...
# Grafana, Microsoft PowerBI, SAP Business Object...                                                  1
# Looker, Metabase, Google Data Studio                                                                1
# ...

# %%
df.columns.to_list()
# Out:
# ["('P0', 'id')",
#  "('P1_a ', 'Idade')",
#  "('P1_a_a ', 'Faixa idade')",
#  "('P1_b ', 'Genero')",
#  "('P1_e ', 'Estado onde mora')",
#  "('P1_e_a ', 'uf onde mora')",
#  'Regiao_onde_mora',
#  "('P1_g_b ', 'Regiao de origem')",
#  "('P1_g_c ', 'Mudou de Estado?')",
#  "('P1_h ', 'Nivel de Ensino')",
#  "('P1_i ', 'Área de Formação')",
#  "('P2_a ', 'Qual sua situação atual de trabalho?')",
#  "('P2_b ', 'Setor')",
#  "('P2_c ', 'Numero de Funcionarios')",
#  "('P2_d ', 'Gestor?')",
#  "('P2_e ', 'Cargo como Gestor')",
#  'cargo_atual',
#  "('P2_g ', 'Nivel')",
#  'salario',
#  "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
#  "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
#  "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
#  "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')",
# ...

# %% [markdown]
# ## GAsta a maior parte do tempo

# %%
df["('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')"].value_counts().to_frame()
# Out:
#                                                     ('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')
# Desenvolvendo pipelines de dados utilizando lin...                                                 46
# Desenvolvendo pipelines de dados utilizando lin...                                                 43
# Desenvolvendo pipelines de dados utilizando lin...                                                 42
# Desenvolvendo pipelines de dados utilizando lin...                                                 27
# Criando consultas através da linguagem SQL para...                                                 24
# Desenvolvendo pipelines de dados utilizando lin...                                                 20
# Desenvolvendo pipelines de dados utilizando lin...                                                 20
# Modelando soluções de arquitetura de dados, cri...                                                 20
# ...

# %% [markdown]
# ## Quais canais participam

# %%
df["('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')"].value_counts().to_frame()
# Out:
#                                                     ('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')
# 0                                                                                                 408
# Ainda não conhecia o Data Hackers                                                                 382
# Blog/Medium do Data Hackers, Podcast do Data Ha...                                                 98
# Blog/Medium do Data Hackers, Podcast do Data Ha...                                                 81
# Podcast do Data Hackers                                                                            80
# ...                                                                                               ...
# Canal do Youtube do Data Hackers, Blog/Medium d...                                                  1
# Canal do Slack, Blog/Medium do Data Hackers, Ca...                                                  1
# ...

# %% [markdown]
# # ver dos maiores salario oque fazem e ver dos dos que usam python

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 classes = [dados.Altura.min(), 1.65, 1.75, dados.Altura.max()]
#       2 labels = ['1 - Baixa', '2 - Média', '3 - Alta']
#       4 frequencia = pd.value_counts(
#       5     pd.cut(
#       6         x = dados.Altura,
#    (...)
#      10     )
#      11 )
#
# NameError: name 'dados' is not defined
